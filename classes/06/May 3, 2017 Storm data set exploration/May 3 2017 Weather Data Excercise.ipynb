# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 37)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..','datasets', 'dataset-06-storms.csv.gz'))
# df = pd.read_csv("/Users/grady/DS-SF-34/classes/06/datasets/dataset-06-storms.csv.gz")
# Out:
# /Users/grady/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# ...         ...                 ...          ...       ...     ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0
#
#           COUNTYNAME STATE      EVTYPE  BGN_RANGE BGN_AZI BGN_LOCATI  \
# 0             MOBILE    AL     TORNADO        0.0     NaN        NaN
# ...

# %%
df2 = df[ ['COUNTYNAME','STATE','EVTYPE','FATALITIES', 'INJURIES','PROPDMG', 'CROPDMG','PROPDMGEXP','CROPDMGEXP'] ]

# %%
df2
# Out:
#           COUNTYNAME STATE      EVTYPE  FATALITIES  INJURIES  PROPDMG  \
# 0             MOBILE    AL     TORNADO         0.0      15.0     25.0
# 1            BALDWIN    AL     TORNADO         0.0       0.0      2.5
# 2            FAYETTE    AL     TORNADO         0.0       2.0     25.0
# 3            MADISON    AL     TORNADO         0.0       2.0      2.5
# 4            CULLMAN    AL     TORNADO         0.0       2.0      2.5
# ...              ...   ...         ...         ...       ...      ...
# 902292  WYZ007 - 017    WY   HIGH WIND         0.0       0.0      0.0
# 902293  MTZ009 - 010    MT   HIGH WIND         0.0       0.0      0.0
# 902294        AKZ213    AK   HIGH WIND         0.0       0.0      0.0
# 902295        AKZ202    AK    BLIZZARD         0.0       0.0      0.0
# 902296        ALZ006    AL  HEAVY SNOW         0.0       0.0      0.0
#
#         CROPDMG PROPDMGEXP CROPDMGEXP
# 0           0.0          K        NaN
# 1           0.0          K        NaN
# ...

# %%
df2.PROPDMGEXP.unique()
# Out:
# array(['K', 'M', nan, 'B', 'm', '+', '0', '5', '6', '?', '4', '2', '3',
#        'h', '7', 'H', '-', '1', '8'], dtype=object)

# %%
df2.EVTYPE.unique()
# Out:
# array(['TORNADO', 'TSTM WIND', 'HAIL', 'FREEZING RAIN', 'SNOW',
#        'ICE STORM/FLASH FLOOD', 'SNOW/ICE', 'WINTER STORM',
#        'HURRICANE OPAL/HIGH WINDS', 'THUNDERSTORM WINDS', 'RECORD COLD',
#        'HURRICANE ERIN', 'HURRICANE OPAL', 'HEAVY RAIN', 'LIGHTNING',
#        'THUNDERSTORM WIND', 'DENSE FOG', 'RIP CURRENT',
#        'THUNDERSTORM WINS', 'FLASH FLOOD', 'FLASH FLOODING', 'HIGH WINDS',
#        'FUNNEL CLOUD', 'TORNADO F0', 'THUNDERSTORM WINDS LIGHTNING',
#        'THUNDERSTORM WINDS/HAIL', 'HEAT', 'WIND', 'LIGHTING',
#        'HEAVY RAINS', 'LIGHTNING AND HEAVY RAIN', 'FUNNEL', 'WALL CLOUD',
#        'FLOODING', 'THUNDERSTORM WINDS HAIL', 'FLOOD', 'COLD',
#        'HEAVY RAIN/LIGHTNING', 'FLASH FLOODING/THUNDERSTORM WI',
#        'WALL CLOUD/FUNNEL CLOUD', 'THUNDERSTORM', 'WATERSPOUT',
#        'EXTREME COLD', 'HAIL 1.75)', 'LIGHTNING/HEAVY RAIN', 'HIGH WIND',
#        'BLIZZARD', 'BLIZZARD WEATHER', 'WIND CHILL', 'BREAKUP FLOODING',
# ...

# %%
df2[['EVTYPE']].groupby('EVTYPE').count()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df2.sort_values('FATALITIES', ascending=False)
# Out:
#                                                COUNTYNAME STATE  \
# 198703  ILZ003>006 - 008 - 010>014 - 019>023 - 032 - 0...    IL
# 862633                                             JASPER    MO
# 68669                                             GENESEE    MI
# 148851                                           MCLENNAN    TX
# 355127                   ILZ005>006 - 012>014 - 020 - 022    IL
# ...                                                   ...   ...
# 302028                                           ANDERSON    SC
# 302029                                        SPARTANBURG    SC
# 302030                                            CALHOUN    SC
# 302031                                           BARNWELL    SC
# 902296                                             ALZ006    AL
#
#                 EVTYPE  FATALITIES  INJURIES  PROPDMG  CROPDMG PROPDMGEXP  \
# 198703            HEAT       583.0       0.0      0.0      0.0        NaN
# ...

# %%
df2['TestColumn'] = df2.FATALITIES + df2.INJURIES + df2.PROPDMG + df2.CROPDMG
# Out:
# /Users/grady/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2
# Out:
#           COUNTYNAME STATE      EVTYPE  FATALITIES  INJURIES  PROPDMG  \
# 0             MOBILE    AL     TORNADO         0.0      15.0     25.0
# 1            BALDWIN    AL     TORNADO         0.0       0.0      2.5
# 2            FAYETTE    AL     TORNADO         0.0       2.0     25.0
# 3            MADISON    AL     TORNADO         0.0       2.0      2.5
# 4            CULLMAN    AL     TORNADO         0.0       2.0      2.5
# ...              ...   ...         ...         ...       ...      ...
# 902292  WYZ007 - 017    WY   HIGH WIND         0.0       0.0      0.0
# 902293  MTZ009 - 010    MT   HIGH WIND         0.0       0.0      0.0
# 902294        AKZ213    AK   HIGH WIND         0.0       0.0      0.0
# 902295        AKZ202    AK    BLIZZARD         0.0       0.0      0.0
# 902296        ALZ006    AL  HEAVY SNOW         0.0       0.0      0.0
#
#         CROPDMG PROPDMGEXP CROPDMGEXP  TestColumn
# 0           0.0          K        NaN        40.0
# ...

# %%
df3 = df2[df2.TestColumn != 0]

# %%
df3
# Out:
#                                                COUNTYNAME STATE        EVTYPE  \
# 0                                                  MOBILE    AL       TORNADO
# 1                                                 BALDWIN    AL       TORNADO
# 2                                                 FAYETTE    AL       TORNADO
# 3                                                 MADISON    AL       TORNADO
# 4                                                 CULLMAN    AL       TORNADO
# ...                                                   ...   ...           ...
# 902249                                             MIZ005    MI  WINTER STORM
# 902254                                       VAZ016 - 032    VA   STRONG WIND
# 902256                                         KYZ001>022    KY   STRONG WIND
# 902258  TXZ091>095 - 100 - 105>107 - 115>117 - 120>123...    TX       DROUGHT
# 902259                                 CAZ506 - 512 - 513    CA     HIGH WIND
#
# ...
