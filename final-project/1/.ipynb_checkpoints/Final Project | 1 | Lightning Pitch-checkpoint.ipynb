# %% [markdown]
# Grady Project Idea 1: Airbnb New User Bookings
#
# The Problem: Predict in which country a new user will make his or her first booking.
#
# The Data - https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings
#
# - id: user id
# - date_account_created: the date of account creation
# - timestamp_first_active: timestamp of the first activity, note that it can be earlier than date_account_created or date_first_booking because a user can search before signing up
# - date_first_booking: date of first booking
# - gender
# - age
# - signup_method
# - signup_flow: the page a user came to signup up from
# - language: international language preference
# - affiliate_channel: what kind of paid marketing
# - affiliate_provider: where the marketing is e.g. google, craigslist, other
# - first_affiliate_tracked: what is the first marketing the user interacted with before the - signing up?
# - signup_app
# - first_device_type
# - first_browser
# - country_destination: this is the target variable you are to predict
# - user_id: to be joined with the column 'id' in users table
# - Action
# - Action_type
# - Action_detail
# - device_type
# - Secs_elapsed
# - countries.csv - summary statistics of destination countries in this dataset and their - locations
# - age_gender_bkts.csv - summary statistics of users' age group, gender, country of destination
# - sample_submission.csv - correct format for submitting your predictions
#
# The Hypothesis: Users who sign up with Airbnb will likely book their first booking within the United States because users will want to get comfortable with the app first before their first booking in other countries.
#
#
#
# Grady Project Idea 2: San Francisco Crime Classification
#
# The Problem: Predict the category of crimes that occurred in the city by the bay
#
# The Data - https://www.kaggle.com/c/sf-crime/data
#
# - Dates - timestamp of the crime incident
# - Category - category of the crime incident (only in train.csv). This is the target variable you are going to predict.
# - Descript - detailed description of the crime incident (only in train.csv)
# - DayOfWeek - the day of the week
# - PdDistrict - name of the Police Department District
# - Resolution - how the crime incident was resolved (only in train.csv)
# - Address - the approximate street address of the crime incident
# - X - Longitude
# - Y - Latitude
#
# The Hypothesis: With rising wealth inequality housing shortages, I believe theft in general will be the most popular category of crime. Other categories that wouldn’t be considered as theft include vandalism, drug/narcotic, and assault.
#
#
#
# Grady Project Idea 3: Bike Sharing Demand
#
# The Problem: Combine historical usage patterns with weather data in order to forecast bike rental demand in the Capital Bikeshare program in Washington, D.C. Predict the total count of bikes rented during each hour covered by the test set.
#
# The Data - https://www.kaggle.com/c/bike-sharing-demand
#
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals
#
# The Hypothesis: Bike rental demand will generally increase during warmer, sunny, or relatively calm weather with low winds. Bike rental demand will generally decrease in stormy weather. Our training set will show this.
